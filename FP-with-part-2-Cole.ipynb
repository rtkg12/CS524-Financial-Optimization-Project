# %%
using CSV
file = "./nyse/Fundamentals with Ratios FINAL/fundementals_with_ratios_training_set.csv"
raw = CSV.read(file);

raw
# Out:
# 618×78 DataFrames.DataFrame. Omitted printing of 74 columns
# │ Row │ Ticker Symbol │ Period Ending │ Accounts Payable │ Accounts Receivable │
# │     │ String⍰       │ String⍰       │ Int64⍰           │ Int64⍰              │
# ├─────┼───────────────┼───────────────┼──────────────────┼─────────────────────┤
# │ 1   │ AAL           │ 31/12/12      │ 3068000000       │ -222000000          │
# │ 2   │ AAL           │ 31/12/13      │ 4975000000       │ -93000000           │
# │ 3   │ AAP           │ 29/12/12      │ 2409453000       │ -89482000           │
# │ 4   │ AAP           │ 28/12/13      │ 2609239000       │ -32428000           │
# │ 5   │ AAP           │ 02/01/16      │ 3757085000       │ -21476000           │
# │ 6   │ AAPL          │ 28/09/13      │ 36223000000      │ -1949000000         │
# │ 7   │ AAPL          │ 24/09/16      │ 59321000000      │ 1044000000          │
# │ 8   │ ABBV          │ 31/12/13      │ 6448000000       │ 681000000           │
# │ 9   │ ABC           │ 30/09/13      │ 14870635000      │ -2312518000         │
# │ 10  │ ABC           │ 30/09/16      │ 24670159000      │ -912724000          │
# ⋮
# │ 608 │ XRX           │ 31/12/12      │ 2654000000       │ 641000000           │
# │ 609 │ XRX           │ 31/12/13      │ 2360000000       │ 573000000           │
# │ 610 │ XYL           │ 31/12/12      │ 775000000        │ 2000000             │
# │ 611 │ XYL           │ 31/12/13      │ 811000000        │ -47000000           │
# │ 612 │ YHOO          │ 31/12/12      │ 993306000        │ 34752000            │
# │ 613 │ YHOO          │ 31/12/13      │ 1045813000       │ 26199000            │
# │ 614 │ YUM           │ 29/12/12      │ 2269000000       │ -18000000           │
# │ 615 │ YUM           │ 28/12/13      │ 2194000000       │ -12000000           │
# │ 616 │ ZBH           │ 31/12/12      │ 206900000        │ -45500000           │
# │ 617 │ ZBH           │ 31/12/13      │ 367500000        │ -74300000           │
# │ 618 │ ZTS           │ 31/12/13      │ 1381000000       │ -99000000           │

# %%
raw[:,78]
# Out:
# 618-element Array{Union{Missing, Float64},1}:
#   46.689999
#   46.689999
#  169.119995
#  169.119995
#  169.119995
#  115.82
#  115.82
#   62.619999
#   78.190002
#   78.190002
#   38.41
#   38.41
#  102.949997
#    ⋮
#   57.73
#    8.73
#    8.73
#   49.52
#   49.52
#   38.669998
#   38.669998
#   63.330002
#   63.330002
#  103.199997
#  103.199997
#   53.529999

# %%
A = []

for i in 3:76
    push!(A, raw[:,i])
end

A
# Out:
# 74-element Array{Any,1}:
#  Union{Missing, Int64}[3068000000, 4975000000, 2409453000, 2609239000, 3757085000, 36223000000, 59321000000, 6448000000, 14870635000, 24670159000  …  2360000000, 775000000, 811000000, 993306000, 1045813000, 2269000000, 2194000000, 206900000, 367500000, 1381000000]
#  Union{Missing, Int64}[-222000000, -93000000, -89482000, -32428000, -21476000, -1949000000, 1044000000, 681000000, -2312518000, -912724000  …  573000000, 2000000, -47000000, 34752000, 26199000, -18000000, -12000000, -45500000, -74300000, -99000000]
#  Union{Missing, Int64}[-1961000000, -2723000000, 600000, 2698000, -7484000, 1156000000, 1348000000, -54000000, -44000, 5048000  …  0, 0, -10000000, 4647839000, 123307000, 0, 0, 15600000, 9600000, 9000000]
#  3.75709e9   -2.1476e7        -7.484e6       9.73702e9   -1.19709e8    6.45
#  3.6223e10   -1.949e9          1.156e9    …  1.71e11      0.0         40.03
#  5.9321e10    1.044e9          1.348e9       2.16e11      0.0          8.35
#  6.448e9      6.81e8          -5.4e7         1.879e10    -3.2e8        2.58
#  1.48706e10  -2.31252e9   -44000.0           8.79592e10  -1.51686e9    1.88
#  2.46702e10  -9.12724e8        5.048e6       1.47e11     -4.39601e9    6.73
#  1.0889e10    3.6e7           -1.26e9     …  1.905e10    -5.591e9      3.76
#  5.948e9     -1.13e8           5.3e7         1.9657e10   -6.844e9      1.64
#  7.29257e8    3.3649e7    926000.0           4.05524e9   -3.64319e9    0.58
#  ⋮                                        ⋱
#  4.86543e8   -3.25e7     -300000.0           2.9508e9    -7.48506e8    2.2
#  2.654e9      6.41e8           0.0           2.0421e10   -1.04e8       0.9
#  2.36e9       5.73e8           0.0           2.0006e10   -2.52e8       0.93
#  7.75e8       2.0e6            0.0           3.791e9     -1.3e7        1.6
#  8.11e8      -4.7e7           -1.0e7      …  3.837e9     -8.6e7        1.23
#  9.93306e8    3.4752e7         4.64784e9     4.98657e9   -1.36804e9    3.31
#  1.04581e9    2.6199e7         1.23307e8     4.68038e9   -2.00228e8    1.3
#  2.269e9     -1.8e7            0.0           1.3633e10    0.0          3.46
#  2.194e9     -1.2e7            0.0           1.3084e10    0.0          2.41
#  2.069e8     -4.55e7           1.56e7     …  4.4717e9    -5.0721e9     4.32
#  3.675e8     -7.43e7           9.6e6         4.6234e9    -5.7857e9     4.49
#  1.381e9     -9.9e7            9.0e6         4.561e9      0.0          1.01

# %%
prices = raw[:78]
shares = raw[:77]

mkt_cap = prices.*shares
y = mkt_cap
# Out:
# 618-element Array{Float64,1}:
#  1.5641149665e10
#  7.611507391495777e9
#  1.239371426576783e10
#  1.2360841603946102e10
#  1.2412568588116007e10
#  1.07160263303394e11
#  6.337087832349199e11
#  1.001919984e11
#  1.8038059150222427e10
#  1.6589862019528402e10
#  6.0914582434549995e10
#  6.0331804865869995e10
#  5.147233599688258e10
#  ⋮
#  8.218652729372e9
#  1.159150000194e10
#  1.087964516007e10
#  9.19215e9
#  9.179317075224e9
#  4.609415861073477e10
#  4.064160273597923e10
#  2.9230639648809387e10
#  2.866930795707619e10
#  1.8036110584894444e10
#  1.793703289113461e10
#  2.6711999501520096e10

# %%
prices
# Out:
# 618-element Array{Union{Missing, Float64},1}:
#   46.689999
#   46.689999
#  169.119995
#  169.119995
#  169.119995
#  115.82
#  115.82
#   62.619999
#   78.190002
#   78.190002
#   38.41
#   38.41
#  102.949997
#    ⋮
#   57.73
#    8.73
#    8.73
#   49.52
#   49.52
#   38.669998
#   38.669998
#   63.330002
#   63.330002
#  103.199997
#  103.199997
#   53.529999

# %%
# NOTE: must have either Gurobi or Mosek installed!

# Solve the LEAST SQUARES polynomial fit

using JuMP, Mosek, Ipopt, Gurobi

#m = Model(solver=ClpSolver())
#m = Model(solver=MosekSolver(LOG=0))
m = Model(solver=GurobiSolver(OutputFlag=0,BarHomogeneous=1))
#m = Model(solver=GurobiSolver(OutputFlag=0,NumericFocus=3,BarHomogeneous=1))
#m = Model(solver=IpoptSolver())

@variable(m, u[1:74])
@objective(m, Min, 1/1000000000000000 * sum( (y - B*u).^2 ) )

status = solve(m)
uopt = getvalue(u)
println(status)
println(getobjectivevalue(m))
println(uopt)
# Out:
# Academic license - for non-commercial use only
# ┌ Warning: Gurobi reported infeasible or unbounded. Set InfUnbdInfo=1 for more specific status.
# └ @ Gurobi C:\Users\Cole\.julia\packages\Gurobi\dlJep\src\MPB_wrapper.jl:440
# ┌ Warning: Not solved to optimality, status: InfeasibleOrUnbounded
# └ @ JuMP C:\Users\Cole\.julia\packages\JuMP\PbnIJ\src\solvers.jl:212
# ┌ Warning: Variable value not defined for component of u. Check that the model was properly solved.
# └ @ JuMP C:\Users\Cole\.julia\packages\JuMP\PbnIJ\src\JuMP.jl:475
# InfeasibleOrUnbounded
# NaN
# [NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN]

# %%
save = uopt
# Out:
# 74-element Array{Float64,1}:
#     4.159642262945208e10
#     3.476573224258896
#   -12.054232260533272
#    -6.924681916698182e6
#   244.42504325392164
#     2.9678151193203233
#    -2.6246657364763014e7
#   378.2129286787726
#    -2.119610169724268
#     0.8459622909254283
#   -71.56295675572038
#    -2.3957600378346607e7
#    48.09208839160924
#     ⋮
#     0.20578411703894517
#     4.1596422630917336e10
#   378.21577952661494
#   -44.51647882405516
#  -335.36427100097205
#    -4.159642263321245e10
#  -135.7734237444554
#  -130.18554995115963
#   138.70807829194442
#    71.40841605626262
#     0.3024462272130988
#     2.847855663690381e7

# %%
test = "./nyse/Fundamentals with Ratios FINAL/fundementals_with_ratios_testing_set.csv"
raw2 = CSV.read(test)

raw2
# Out:
# 307×78 DataFrames.DataFrame. Omitted printing of 74 columns
# │ Row │ Ticker Symbol │ Period Ending │ Accounts Payable │ Accounts Receivable │
# │     │ String⍰       │ Dates…⍰       │ Int64⍰           │ Int64⍰              │
# ├─────┼───────────────┼───────────────┼──────────────────┼─────────────────────┤
# │ 1   │ AAL           │ 2014-12-31    │ 4668000000       │ -160000000          │
# │ 2   │ AAPL          │ 2014-09-27    │ 48649000000      │ -6452000000         │
# │ 3   │ ABC           │ 2014-09-30    │ 17250160000      │ -938286000          │
# │ 4   │ ABT           │ 2014-12-31    │ 5350000000       │ -195000000          │
# │ 5   │ ADBE          │ 2014-11-28    │ 776163000        │ 7928000             │
# │ 6   │ ADI           │ 2014-11-01    │ 430621000        │ -36460000           │
# │ 7   │ ADM           │ 2014-12-31    │ 15240000000      │ 425000000           │
# │ 8   │ ADS           │ 2014-12-31    │ 914058000        │ -156003000          │
# │ 9   │ ADSK          │ 2014-01-31    │ 375300000        │ 72300000            │
# │ 10  │ AEE           │ 2014-12-31    │ 842000000        │ 31000000            │
# ⋮
# │ 297 │ WYN           │ 2014-12-31    │ 1134000000       │ -250000000          │
# │ 298 │ WYNN          │ 2014-12-31    │ 728686000        │ 38000               │
# │ 299 │ XEC           │ 2014-12-31    │ 740552000        │ -35133000           │
# │ 300 │ XEL           │ 2014-12-31    │ 1879877000       │ -166408000          │
# │ 301 │ XLNX          │ 2014-03-29    │ 369260000        │ -38658000           │
# │ 302 │ XOM           │ 2014-12-31    │ 47165000000      │ 3118000000          │
# │ 303 │ XRAY          │ 2014-12-31    │ 540800000        │ 7200000             │
# │ 304 │ XRX           │ 2014-12-31    │ 2338000000       │ 67000000            │
# │ 305 │ YHOO          │ 2014-12-31    │ 4178020000       │ 29278000            │
# │ 306 │ YUM           │ 2014-12-27    │ 2142000000       │ -21000000           │
# │ 307 │ ZBH           │ 2014-12-31    │ 225500000        │ -40400000           │

# %%
AAPL = raw2[302,3:76]
# Out:
# DataFrameRow. Omitted printing of 71 columns
# │ Row │ Accounts Payable │ Accounts Receivable │ Add'l income/expense items │
# │     │ Int64⍰           │ Int64⍰              │ Union{Missing, Int64}      │
# ├─────┼──────────────────┼─────────────────────┼────────────────────────────┤
# │ 302 │ 47165000000      │ 3118000000          │ 4511000000                 │

# %%
using LinearAlgebra
AAPL = convert(Array, AAPL)
# Out:
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = top-level scope at In[49]:2
# └ @ Core In[49]:2
# 1×74 Array{Any,2}:
#  47165000000  3118000000  4511000000  19  …  3.49e11  3.94e11  -2.26e11  7.6

# %%
AAPL_Test = AAPL * save
# Out:
# 1-element Array{Any,1}:
#  4.078281678041825e11

# %%
AAPL_shares = raw2[302,77]
# Out:
# 4.278947368e9

# %%
AAPL_price = raw2[302, 78]
# Out:
# 92.449997

# %%
AAPL_shares * AAPL_price
# Out:
# 3.955886713347579e11

# %%
AAPL_Test/AAPL_shares
# Out:
# 1-element Array{Float64,1}:
#  95.31039592917529

# %% [markdown]
# ### Part 2:

# %%
using CSV, LinearAlgebra

μ = convert(Vector, CSV.read("./nyse/Portfolio calculations/expected-return-risk.csv", header = true)[2])  # Expected return (in percent)
Σ = convert(Matrix, CSV.read("./nyse/Portfolio calculations/covariance-matrix.csv", header=false))   # Expected variance (in percent squared)
tickers = convert(Vector, CSV.read("./nyse/Portfolio calculations/expected-return-risk.csv", header = true)[1])  # Tickers

#ix = 1:307;   
ix = sortperm(μ) # get order of indices which will sort the assets by expected return
nAssets = 307

using PyPlot
fig = figure(figsize=(12,6))

subplot(211)
xlim(0,nAssets)
plot(sqrt.(diag(Σ))[ix],"g")
ylabel("Standard deviation (%)")
title("Standard deviation and expected return of all 307 assets")
tight_layout()

subplot(212)
xlim(0,nAssets)
plot(μ[ix])
plot([0,nAssets],[0,0],"r--")
ylabel("Expected return (%)")
tight_layout()
#savefig("folio1_vals.pdf")
;
# Out:
# Figure(PyObject <Figure size 1200x600 with 2 Axes>)

# %%
# plot correlation matrix (shows which assets are correlated with which other assets)
corr = diagm(0 => diag(Σ).^(-1/2))*Σ*diagm(0 => diag(Σ).^(-1/2))
imshow(corr[ix,ix]);colorbar();axis("image")
title("Correlation matrix for 307 assets")
tight_layout()
#savefig("folio2_cov.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# plot each asset individually
figure(figsize=(7,5))
plot(sqrt.(diag(Σ)), μ, "b.")
xlabel("std deviation (%)")
ylabel("expected return (%)")
tight_layout()
#savefig("folio3_assets.pdf")
;
# Out:
# Figure(PyObject <Figure size 700x500 with 1 Axes>)

# %%
# find optimal portfolio for one particular choice of λ
using JuMP, Mosek
m = Model(solver = MosekSolver(LOG=0))
@variable(m, x[1:nAssets] >= 0) # Investment amounts non-negative (cannot sell short assets)
@constraint(m, sum(x) == 1)     # Must invest all of portfolio

figure(figsize=(12,8))

subplot(211)
λ = 1

@objective(m, Min, -dot(μ,x) + λ*dot(x,Σ*x) )
solve(m)
xsol1 = getvalue(x)
ix1 = findall(xsol1 .> 1e-4)
ret1 = dot(μ,xsol1)
std1 = sqrt(dot(xsol1,Σ*xsol1))
xlim(0,nAssets)
bar(1:nAssets,xsol1[ix])
title(string("Optimal asset selection for \$\\lambda=1\$"," ( \$\\mu=\$", round(ret1,digits=3), "%, \$\\sigma=\$", round(std1,digits=2), "% )"));
tight_layout()
subplot(212)
λ = 3e-2

@objective(m, Min, -dot(μ,x) + λ*dot(x,Σ*x) )
solve(m)
xsol2 = getvalue(x)
ix2 = findall(xsol2 .> 1e-4)
ret2 = dot(μ,xsol2)
std2 = sqrt(dot(xsol2,Σ*xsol2))
xlim(0,nAssets)
bar(1:nAssets,xsol2[ix])
title(string("Optimal asset selection for \$\\lambda=3\$ x \$ 10^{2}\$"," ( \$\\mu=\$", round(ret2,digits=3), "%, \$\\sigma=\$", round(std2,digits=2), "% )"));
tight_layout()
# Out:
# Figure(PyObject <Figure size 1200x800 with 2 Axes>)

# %%
figure(figsize=(12,8))
subplot(211)
λ = 0.1

@objective(m, Min, -dot(μ,x) + λ*dot(x,Σ*x) )
solve(m)
xsol3 = getvalue(x)
ix3 = findall(xsol3 .> 1e-4)
ret3 = dot(μ,xsol3)
std3 = sqrt(dot(xsol3,Σ*xsol3))
xlim(0,nAssets)
bar(1:nAssets,xsol3[ix])
title(string("Optimal asset selection for \$\\lambda=0.1\$"," ( \$\\mu=\$", round(ret3,digits=3), "%, \$\\sigma=\$", round(std3,digits=2), "% )"));
tight_layout()


#savefig("folio4_optassets.pdf")
# Out:
# Figure(PyObject <Figure size 1200x800 with 1 Axes>)

# %%
for i in 1:length(ix2)
    println("Company: - ", tickers[ix2[i]], " % Alloc: ", xsol2[ix2[i]]*100)
end
# Out:
# Company: - AAL % Alloc: 11.205167456487324
# Company: - ALXN % Alloc: 10.843182660174252
# Company: - BIIB % Alloc: 16.77185056964966
# Company: - CMG % Alloc: 20.29391858186632
# Company: - GILD % Alloc: 1.3100748101025927
# Company: - NFLX % Alloc: 12.734996926003006
# Company: - ORLY % Alloc: 5.498483550847415
# Company: - REGN % Alloc: 19.05584283333234
# Company: - TSCO % Alloc: 2.285836172240937

# %%
# compute optimal tradeoff curve (this may take a few seconds)
N = 50
ret = zeros(N)
std = zeros(N)
lambda_values = exp10.(range(-3,stop=4,length=N))

for (i,λ) in enumerate(lambda_values)
    @objective(m, Min, -dot(μ,x) + λ*dot(x,Σ*x) )
    solve(m)
    xsol = getvalue(x)
    ret[i] = dot(μ,xsol)
    std[i] = sqrt(dot(xsol,Σ*xsol))
end

# %%
# plot tradeoff curve
plot(std,ret,"b-")
plot(sqrt.(diag(Σ)), μ, "k.", markersize=12)
#plot(sqrt.(diag(Σ))[ix1], μ[ix1], "r.", markersize=12)  # low-risk portfolio
plot(sqrt.(diag(Σ))[ix2], μ[ix2], "c.", markersize=12)  # at the "elbow" of the curve
#plot(sqrt.(diag(Σ))[ix3], μ[ix3], "g.", markersize=12)  # lambda = 0.1
xlabel("std deviation (%)")
ylabel("expected return (%)")
#axis([1.5,4.5,0,.4]);
tight_layout()
#savefig("folio5_pareto.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
