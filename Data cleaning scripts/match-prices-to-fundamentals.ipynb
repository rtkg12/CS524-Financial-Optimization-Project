# %%
import pandas as pd

fundamental_files = ["./nyse/Fundamentals with Ratios FINAL/fundementals_with_ratios_testing_set.csv", "./nyse/Fundamentals with Ratios FINAL/fundementals_with_ratios_training_set.csv", "./nyse/Fundamentals with Ratios FINAL/fundementals_with_ratios_validation_set.csv"]
prices = pd.read_csv('./nyse/prices.csv')
prices.head()
# Out:
#          date symbol        open       close         low        high   volume
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600

# %%
raw = pd.read_csv(fundamental_files[1])
raw.head()
# Out:
#   Ticker Symbol Period Ending  Accounts Payable  Accounts Receivable  \
# 0           AAL    2012-12-31        3068000000           -222000000
# 1           AAL    2013-12-31        4975000000            -93000000
# 2           AAP    2012-12-29        2409453000            -89482000
# 3           AAP    2013-12-28        2609239000            -32428000
# 4           AAP    2016-01-02        3757085000            -21476000
#
#    Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# 0                 -1961000000             23           -1888000000
# 1                 -2723000000             67           -3114000000
# 2                      600000             32            -271182000
# 3                     2698000             26            -195757000
# 4                    -7484000             19            -234747000
#
#    Capital Surplus  Cash Ratio  Cash and Cash Equivalents  ...  \
# 0       4695000000          53                 1330000000  ...
# ...

# %%
raw.loc[raw['Ticker Symbol']=='AAPL']
# Out:
#   Ticker Symbol Period Ending  Accounts Payable  Accounts Receivable  \
# 1          AAPL    2014-09-27       48649000000          -6452000000
#
#    Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# 1                   980000000             35           -9571000000
#
#    Capital Surplus  Cash Ratio  Cash and Cash Equivalents  ...  Total Assets  \
# 1                0          40                13844000000  ...  2.320000e+11
#
#    Total Current Assets  Total Current Liabilities  Total Equity  \
# 1          6.853100e+10                63448000000  1.120000e+11
#
#    Total Liabilities  Total Liabilities & Equity  Total Revenue  \
# 1       1.200000e+11                2.320000e+11   1.830000e+11
#
#    Treasury Stock  Earnings Per Share  Estimated Shares Outstanding
# 1             0.0                6.49                  6.087827e+09
#
# [1 rows x 77 columns]

# %%
a = prices.loc[prices['symbol']=='AAPL']
a = a.loc[a['date']<='2014-09-27']
a.tail(1)
# Out:
#               date symbol       open   close        low    high      volume
# 567606  2014-09-26   AAPL  98.529999  100.75  98.400002  100.75  62370500.0

# %%
def match_prices(file):
    raw = pd.read_csv(file)
    
    stock_symbols = raw['Ticker Symbol'].drop_duplicates()
    prices_matched = []
    # Get stock prices in raw df
    for s in stock_symbols:
        date_arr = raw.loc[raw['Ticker Symbol']==s]['Period Ending']
        #print(date_arr)
        for date in date_arr:
            #print(date, " ", s)
            temp = prices.loc[prices['symbol']==s]
            temp1 = temp.loc[temp['date']<=date]
            temp2 = temp.loc[temp['date']>=date]
            if temp1.empty:
                temp = temp2.head(1)
            else:
                temp = temp1.tail(1)
            #print(temp)
            #print(date)
            close_price = temp['close'].values[0]
            prices_matched.append(close_price)
            print(date, " ", s, " " ,close_price)
        
    raw['Close'] = prices_matched
    raw.to_csv(file, index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
match_prices(fundamental_files[0])
match_prices(fundamental_files[1])
match_prices(fundamental_files[2])
# Out:
# 2014-12-31   AAL   53.630001
# 2014-09-27   AAPL   100.75
# 2014-09-30   ABC   77.300003
# 2014-12-31   ABT   45.02
# 2014-11-28   ADBE   73.68
# 2014-11-01   ADI   49.619999
# 2014-12-31   ADM   52.0
# 2014-12-31   ADS   286.049988
# 2014-01-31   ADSK   51.25
# 2014-12-31   AEE   46.130001
# 2014-12-31   AKAM   62.959998999999996
# 2014-12-31   ALB   60.130001
# 2014-12-31   ALK   59.759997999999996
# 2014-12-31   ALXN   185.029999
# 2014-10-26   AMAT   20.99
# 2014-12-31   AME   52.630001
# 2014-12-31   AMGN   159.28999299999998
# 2014-12-31   AMT   98.849998
# 2014-12-31   AMZN   310.350006
# 2014-12-31   AN   60.41
# 2014-12-31   APA   62.669998
# 2014-12-31   APC   82.5
# 2014-09-30   APD   130.179994
# 2014-12-31   APH   53.810001
# 2014-12-31   ARNC   15.790013
# 2014-12-31   ATVI   20.15
# 2014-12-31   AWK   53.299999
# 2014-08-31   AYI   123.879997
# 2014-08-30   AZO   538.840027
# 2014-12-31   BA   129.979996
# 2014-12-31   BAX   73.29
# 2014-03-01   BBBY   67.82
# ...

# %%
raw
# Out:
#     Ticker Symbol Period Ending  Accounts Payable  Accounts Receivable  \
# 0             AAL    2012-12-31        3068000000           -222000000
# 1             AAL    2013-12-31        4975000000            -93000000
# 2             AAP    2012-12-29        2409453000            -89482000
# 3             AAP    2013-12-28        2609239000            -32428000
# 4             AAP    2016-01-02        3757085000            -21476000
# 5            AAPL    2013-09-28       36223000000          -1949000000
# 6            AAPL    2016-09-24       59321000000           1044000000
# 7            ABBV    2013-12-31        6448000000            681000000
# 8             ABC    2013-09-30       14870635000          -2312518000
# 9             ABC    2016-09-30       24670159000           -912724000
# 10            ABT    2012-12-31       10889000000             36000000
# 11            ABT    2013-12-31        5948000000           -113000000
# ...

# %%
stock_symbols = raw['Ticker Symbol']
prices_matched = []

for s in stock_symbols:
    date = raw.loc[raw['Ticker Symbol']==s]['Period Ending'].values[0]
    temp = prices.loc[prices['symbol']==s]
    temp = temp.loc[temp['date']<=date]
    temp = temp.tail(1)
    close_price = temp['close'].values[0]
    prices_matched.append(close_price)
    #print(close_price)

# %%
prices_matched
# Out:
# [53.630001,
#  100.75,
#  77.300003,
#  45.02,
#  73.68,
#  49.619999,
#  52.0,
#  286.049988,
#  51.25,
#  46.130001,
#  62.959998999999996,
#  60.130001,
#  59.759997999999996,
#  185.029999,
#  20.99,
#  52.630001,
#  159.28999299999998,
#  98.849998,
#  310.350006,
#  60.41,
#  62.669998,
#  82.5,
#  120.425526365,
#  53.810001,
#  11.8365914543,
#  20.15,
#  53.299999,
#  123.879997,
#  538.840027,
#  129.979996,
#  39.8098859316,
#  67.82,
#  23.540001,
#  166.619995,
#  113.809998,
#  56.07,
#  339.450012,
#  68.16999799999999,
#  59.029999,
#  13.25,
#  54.950001,
#  24.599221789899996,
#  68.559998,
#  91.529999,
#  34.25,
#  78.699997,
#  44.16,
#  111.860001,
#  54.507999399999996,
#  39.404999,
#  19.57,
#  74.889999,
#  69.190002,
#  91.400002,
#  684.51001,
#  144.169998,
#  34.75,
#  23.43,
#  29.610001,
#  78.5,
#  121.08000200000001,
#  41.959998999999996,
#  60.529999,
#  25.969998999999998,
#  36.68,
#  62.119999,
#  39.580002,
#  52.66,
#  63.799999,
# ...

# %%
x = raw.loc[raw['Ticker Symbol']=='MSFT']['Period Ending'].values[0]
x
# Out:
# '2014-06-30'

# %%
prices_matched.append(1)
prices_matched.append(2)

prices_matched
# Out:
# [1, 2]

# %%
raw['Close'] = prices_matched

# %%
raw.head(1)
# Out:
#   Ticker Symbol Period Ending  Accounts Payable  Accounts Receivable  \
# 0           AAL    2014-12-31        4668000000           -160000000
#
#    Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# 0                  -150000000            143           -5311000000
#
#    Capital Surplus  Cash Ratio  Cash and Cash Equivalents  ...  \
# 0      15135000000          60                 1768000000  ...
#
#    Total Current Assets  Total Current Liabilities  Total Equity  \
# 0          1.175000e+10                13404000000  2.021000e+09
#
#    Total Liabilities  Total Liabilities & Equity  Total Revenue  \
# 0       4.120400e+10                4.322500e+10   4.265000e+10
#
#    Treasury Stock  Earnings Per Share  Estimated Shares Outstanding      Close
# 0             0.0                4.02                   716915422.9  53.630001
#
# [1 rows x 78 columns]

# %%
a = raw.loc[raw['Ticker Symbol']=='AAPL']['Period Ending']
a
# Out:
# 5    2013-09-28
# 6    2016-09-24
# Name: Period Ending, dtype: object

# %%
for i in a:
    print(i)
# Out:
# 2013-09-28
# 2016-09-24

# %%
stock_symbols = raw['Ticker Symbol']
stock_symbols
# Out:
# 0       AAL
# 2       AAP
# 5      AAPL
# 7      ABBV
# 8       ABC
# 10      ABT
# 12     ADBE
# 13      ADI
# 15      ADM
# 16      ADS
# 18     ADSK
# 20      AEE
# 22      AEP
# 24     AKAM
# 26      ALB
# 28      ALK
# 30     ALXN
# 31     AMAT
# 33      AME
# 35     AMGN
# 36      AMT
# 38     AMZN
# 39       AN
# 40      APA
# 42      APC
# 43      APD
# 45      APH
# 47     ARNC
# 49     ATVI
# 51      AVY
#        ...
# 562    VIAB
# 564     VLO
# 566     VMC
# 568    VRSK
# 570    VRSN
# 572    VRTX
# 574      VZ
# 576     WDC
# 578     WEC
# 580     WFM
# 582     WHR
# 583      WM
# 584     WMB
# 586     WMT
# 588     WRK
# 589      WU
# 591      WY
# 593     WYN
# 595    WYNN
# 597     XEC
# 599     XEL
# 601    XLNX
# 603     XOM
# 605    XRAY
# 607     XRX
# 609     XYL
# 611    YHOO
# 613     YUM
# 615     ZBH
# 617     ZTS
# Name: Ticker Symbol, Length: 353, dtype: object
